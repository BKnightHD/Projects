# %% [markdown]
# <a href="https://colab.research.google.com/github/BKnightHD/Projects/blob/BKnightHD-patch-1/F1%20EDA/Notebooks/F1%20EDA%20Notebook%205-7-2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# F1 project - Exploratory Data Analysis
